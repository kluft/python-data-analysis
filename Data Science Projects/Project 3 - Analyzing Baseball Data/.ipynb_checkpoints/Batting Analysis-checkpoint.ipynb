# %% [markdown]
# # Analyzing MLB Batting Statistics: Is Salary Commensurate with Skill

# %% [markdown]
# ## Introduction
#
# Baseball is known as America's favourite past time, millions of people tune in to watch and cheer for their favourite team. This sport has grown so large there are statistics for almost everything in the game. One of the more well known aspects is batting, and generally speaking, the more you can hit the more you will be paid.
#
# Our intuition states that there should be a high correlation between how much they are paid and the statistics for the individual. However, I would like to investigate this further by looking at groups of individuals and comparing several different averaged batting statistics to their average salary interval.
#
# The statistics that will be compared are:
# - Strike-outs per At Bats
# - Home-runs per At Bats
# - Hits per At Bats
# - Walk to Strike-out Ratio
#
# Each of these statistics will be explained in more detail as the analysis progresses.
#
# ### Summary of Results
#
# Our analysis has determined that as a salary interval increases, in general, so does the stats of each individual.

# %% [markdown]
# ## Data Exploration
#
# The baseball database we will be working with was created by Sean Lahman and can be found on his website [here](http://www.seanlahman.com/baseball-archive/statistics/), the database itself can be downloaded directly from [here](https://s3.amazonaws.com/dq-content/224/lahman2015.sqlite).
#
# Before the database can be used we need to explore it first so we know what data it contains.

# %%
import sqlite3
conn = sqlite3.connect('lahman2015.sqlite')
c = conn.cursor()

set_headers = ".headers on"

query = "SELECT name FROM sqlite_master WHERE type='table';"
query1 = c.execute(query).fetchall()
print("Name of the tables found in the database:","\n\n", query1,'\n')

query = "select * from Batting limit 1"
query2 = c.execute(query).fetchall()
fieldnames=[f[0] for f in c.description]
print("Name of the columns in the Batting table:", "\n\n",fieldnames, '\n')

query = "select * from Salaries limit 1"
query2 = c.execute(query).fetchall()
fieldnames=[f[0] for f in c.description]
print("Name of the columns in the Salaries table:", "\n\n",fieldnames, "\n")

query = "select * from Master limit 1"
query2 = c.execute(query).fetchall()
fieldnames=[f[0] for f in c.description]
print("Name of the columns in the Master table:", "\n\n",fieldnames)
# Out:
# Name of the tables found in the database:
#
#  [('AllstarFull',), ('Appearances',), ('AwardsManagers',), ('AwardsPlayers',), ('AwardsShareManagers',), ('AwardsSharePlayers',), ('Batting',), ('BattingPost',), ('CollegePlaying',), ('Fielding',), ('FieldingOF',), ('FieldingPost',), ('HallOfFame',), ('Managers',), ('ManagersHalf',), ('Master',), ('Pitching',), ('PitchingPost',), ('Salaries',), ('Schools',), ('SeriesPost',), ('Teams',), ('TeamsFranchises',), ('TeamsHalf',)]
#
# Name of the columns in the Batting table:
#
#  ['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'G', 'G_batting', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH', 'SF', 'GIDP', 'G_old']
#
# Name of the columns in the Salaries table:
#
#  ['yearID', 'teamID', 'lgID', 'playerID', 'salary']
#
# Name of the columns in the Master table:
#
#  ['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry', 'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay', 'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast', 'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame', 'retroID', 'bbrefID']

# %% [markdown]
# From exploring the database and tables above we see that we have all the information we need to conduct our analysis.
#
# ## Data Gathering
#
# We can now gather the batters name, year, salary, at bats, hits, home-runs, strike-outs, and walks by joining these three tables together. Once we have gathered this data we can create a dataframe using the results to analyze further using the pandas toolkit.

# %%
import pandas as pd
query = '''Select Master.nameGiven, Batting.yearID, Salaries.salary, 
Batting.H, Batting.HR, Batting.AB, Batting.SO, Batting.BB
From Batting 
    Inner Join Salaries 
        on Batting.playerID == Salaries.playerID and batting.yearID == Salaries.yearID
    Inner Join Master
        on Batting.playerID == Master.playerID
Where Batting.yearID > 2000
;'''

baseball_data = pd.read_sql(query,conn)
print(baseball_data.head(10))
# Out:
#         nameGiven  yearID     salary    H  HR   AB   SO   BB
# 0   Garret Joseph    2001  4500000.0  194  28  672  100   27
# 1  Kimera Anotchi    2001   270000.0    0   0   15    5    2
# 2      David Mark    2001   200000.0  166   4  582   60   43
# 3   Darin Charles    2001  3450000.0  163   9  631  113   62
# 4           Jorge    2001   500000.0   33   2  148   15    3
# 5  Romar Benjamin    2001   350000.0   77   8  260   57   14
# 6     Troy Edward    2001  1250000.0  147  41  588  158  107
# 7      Shigetoshi    2001  1500000.0    0   0    0    0    0
# 8       Glenallen    2001  1500000.0    9   1   66   20    0
# 9   Michael James    2001   705000.0    0   0    0    0    0

# %% [markdown]
# ## Data Analysis
#
# Before we can continue with our analysis we will have to set up some filters as we can see that some individuals didn't have any stats for that year. There are multiple reasons for this, but ultimately they never played any games in the MLB league.
#
# ### Data Filtering
#
# As a filter, let's find the mean value and once we have this we can use this as the filter limit. Anything over the median will be included in the analysis and anything under won't be included.

# %%
print('Average At Bats (AB): ', baseball_data.mean(axis=0)[4])
# Out:
# Average At Bats (AB):  165.217781098

# %% [markdown]
# In the above calculation, we can see that the limit for the AB will be 165.

# %%
baseball_data_filtered = baseball_data[baseball_data['AB'] >= 165]

baseball_col_names = ['Name', 'Year', 'Salary', 'H','HR','AB','SO','BB']
baseball_data_filtered.columns = baseball_col_names
print(baseball_data_filtered.head(10))
# Out:
#               Name  Year     Salary    H  HR   AB   SO   BB
# 0    Garret Joseph  2001  4500000.0  194  28  672  100   27
# 2       David Mark  2001   200000.0  166   4  582   60   43
# 3    Darin Charles  2001  3450000.0  163   9  631  113   62
# 5   Romar Benjamin  2001   350000.0   77   8  260   57   14
# 6      Troy Edward  2001  1250000.0  147  41  588  158  107
# 11     Adam Thomas  2001   280000.0  129   6  478   71   27
# 13   Benjamin Jose  2001   350000.0   85   6  325   51   16
# 16         Orlando  2001   900000.0   56   2  230   24   25
# 20   Timothy James  2001  6500000.0  108  17  475  121   96
# 22    Scott Edward  2001  1125000.0  124  13  457   65   34

# %% [markdown]
# This new filtered dataframe contains only the filtered values we are looking for.
#
# ### Data Statistics

# %%
unique_names = baseball_data_filtered['Name'].unique()

name = baseball_data_filtered[baseball_data_filtered['Name'] == 'Garret Joseph']
print(name)
# Out:
#                Name  Year      Salary    H  HR   AB   SO  BB
# 0     Garret Joseph  2001   4500000.0  194  28  672  100  27
# 915   Garret Joseph  2002   5000000.0  195  29  638   80  30
# 1804  Garret Joseph  2003   5350000.0  201  29  638   83  31
# 2700  Garret Joseph  2004   6200000.0  133  14  442   75  29
# 3964  Garret Joseph  2005   9600000.0  163  17  575   84  23
# 4851  Garret Joseph  2006  10600000.0  152  17  543   95  38
# 5764  Garret Joseph  2007  11600000.0  124  16  417   54  27
# 6649  Garret Joseph  2008  12600000.0  163  15  557   77  29
# 7186  Garret Joseph  2009   2500000.0  133  13  496   73  27

# %% [markdown]
# Here we can see some names will have more than one year and data attached to them. If we use the groupby function we can sum each of these columns togeter, then remove the year column as it is no longer necessary. To make our lives easier we can also create the actual statistics we would like to compare as well.

# %%
grouped_baseball_data = baseball_data_filtered.groupby(by=['Name']).sum()
grouped_baseball_data = grouped_baseball_data[['Salary','H','HR','AB','SO','BB']]
grouped_baseball_data['SO/AB (%)'] = (grouped_baseball_data['SO']/grouped_baseball_data['AB'])*100
grouped_baseball_data['HR/AB (%)'] = (grouped_baseball_data['HR']/grouped_baseball_data['AB'])*100
grouped_baseball_data['H/AB (%)'] = (grouped_baseball_data['H']/grouped_baseball_data['AB'])*100
grouped_baseball_data['BB/SO (%)'] = (grouped_baseball_data['BB']/grouped_baseball_data['SO'])*100

print(grouped_baseball_data.head(10))
# Out:
#                      Salary     H   HR    AB   SO   BB  SO/AB (%)  HR/AB (%)  \
# Name
# Aaron John       18575000.0   739   98  2865  533  232  18.603839   3.420593
# Aaron Michael      997500.0    94    9   467  140   60  29.978587   1.927195
# Aaron Ryan       56565000.0  1112  126  4094  865  239  21.128481   3.077675
# Aaron Wade        3876000.0   721   19  2519  259  148  10.281858   0.754268
# Aaron Walter     46731000.0  1255  146  4715  715  345  15.164369   3.096501
# Abraham            300000.0    50    5   221   48   25  21.719457   2.262443
# Abraham Orlando   4825000.0   385   11  1621  292  162  18.013572   0.678593
# Adam Alan        30911800.0   887  144  3233  673  302  20.816579   4.454067
# Adam Cory         1852000.0   384   18  1346  258  118  19.167905   1.337296
# Adam La Marque   45856666.0  1284  193  4589  930  213  20.265853   4.205709
#
#                   H/AB (%)  BB/SO (%)
# Name
# Aaron John       25.794066  43.527205
# Aaron Michael    20.128480  42.857143
# Aaron Ryan       27.161700  27.630058
# Aaron Wade       28.622469  57.142857
# Aaron Walter     26.617179  48.251748
# Abraham          22.624434  52.083333
# Abraham Orlando  23.750771  55.479452
# Adam Alan        27.435818  44.873700
# Adam Cory        28.528975  45.736434
# Adam La Marque   27.979952  22.903226

# %% [markdown]
# The above print out is a small portion of the data we will be using but outlines the new important statistics we would like to explore.
#
# **SO/AB** - Strike-outs per At Bats is a normalization of data providing us with a percentage of times the batter has been struck out compared the number of times they have stepped up to the plate. The smaller this value the better.
#
# **HR/AB** - Home-runs per At Bats is a normalization of data providing us with the percentage of the batter has hit a home run compared to the number times they have stepped up to the plate. The larger this value the better.
#
# **H/AB** - Hits per At Bats is a normalization of data providing us with the percentage of times the batter has a hit compared to the number of times they have stepped up to the plate. The larger this value the better.
#
# **BB/SO** - Walks per Strike-outs is a normalization of data providing us with a percentage of the amount of time a batter ends up walking compared to the amount of strike-outs they have. The larger this value the better.
#
# ### High Level Analysis
#
# Now that we have our statistics let's determine the low, med, and high salaried groupings we want in order to get a better understanding of our hypothesis.

# %%
import math

lowest_salaried = grouped_baseball_data.head(20)
highest_salaried = grouped_baseball_data.tail(20)

midpoint = math.floor(grouped_baseball_data.shape[0]/2)
medium_salaried = grouped_baseball_data.iloc[midpoint-10:midpoint+10]

print(lowest_salaried,"\n",medium_salaried,"\n",highest_salaried)
# Out:
#                       Salary     H   HR    AB    SO    BB  SO/AB (%)  \
# Name
# Aaron John        18575000.0   739   98  2865   533   232  18.603839
# Aaron Michael       997500.0    94    9   467   140    60  29.978587
# Aaron Ryan        56565000.0  1112  126  4094   865   239  21.128481
# Aaron Wade         3876000.0   721   19  2519   259   148  10.281858
# Aaron Walter      46731000.0  1255  146  4715   715   345  15.164369
# Abraham             300000.0    50    5   221    48    25  21.719457
# Abraham Orlando    4825000.0   385   11  1621   292   162  18.013572
# Adam Alan         30911800.0   887  144  3233   673   302  20.816579
# Adam Cory          1852000.0   384   18  1346   258   118  19.167905
# Adam La Marque    45856666.0  1284  193  4589   930   213  20.265853
# Adam Marcos         410000.0    69    7   255    65    19  25.490196
# Adam Michael        357500.0    55   11   214    47    16  21.962617
# Adam Ross           401000.0    40    4   205    63     8  30.731707
# Adam Thomas       20575000.0  1150   59  4244   672   325  15.834119
# Adam Troy        112695000.0  1518  433  6429  2234  1231  34.748795
# Adeiny             6875000.0   403    9  1549   260    79  16.785023
# Adrian           163750000.0  2429  371  8469  1296   596  15.302869
# Adrian Demond       450000.0    45    1   208    34    19  16.346154
# Adrian Sabin     102573785.0  1705  280  5834  1135   673  19.454919
# Akinori           12300000.0   409   16  1514   320   178  21.136063
#
#                  HR/AB (%)   H/AB (%)  BB/SO (%)
# Name
# Aaron John        3.420593  25.794066  43.527205
# Aaron Michael     1.927195  20.128480  42.857143
# Aaron Ryan        3.077675  27.161700  27.630058
# Aaron Wade        0.754268  28.622469  57.142857
# Aaron Walter      3.096501  26.617179  48.251748
# Abraham           2.262443  22.624434  52.083333
# Abraham Orlando   0.678593  23.750771  55.479452
# Adam Alan         4.454067  27.435818  44.873700
# Adam Cory         1.337296  28.528975  45.736434
# Adam La Marque    4.205709  27.979952  22.903226
# Adam Marcos       2.745098  27.058824  29.230769
# Adam Michael      5.140187  25.700935  34.042553
# Adam Ross         1.951220  19.512195  12.698413
# Adam Thomas       1.390198  27.097078  48.363095
# Adam Troy         6.735107  23.611759  55.102954
# Adeiny            0.581020  26.016785  30.384615
# Adrian            4.380682  28.681072  45.987654
# Adrian Demond     0.480769  21.634615  55.882353
# Adrian Sabin      4.799451  29.225231  59.295154
# Akinori           1.056803  27.014531  55.625000
#                              Salary     H   HR    AB   SO   BB  SO/AB (%)  \
# Name
# Johnathan Richard       26208000.0   760  121  3261  849  284  26.034959
# Johnny Arthur             516250.0   123    4   453   59   32  13.024283
# Johnny David           103350000.0  1829  166  6472  880  711  13.597033
# Johnny Pulado            6172500.0   486   34  1675  187   84  11.164179
# Jolbert Alexis           1672000.0   270   13   993  173   49  17.421954
# Jon Corey               31385166.0   986  158  3617  822  279  22.726016
# Jon Lewis                 810000.0   191   11   756  128   61  16.931217
# Jonathan Alejandro       1801000.0   184    7   701  103   58  14.693295
# Jonathan Charles         6766000.0   635   62  2223  347  199  15.609537
# Jonathan Henry           8819000.0   590   25  2069  369  161  17.834703
# Jonathan Johnson        18313600.0   592  110  2457  769  314  31.298331
# Jonathan Lee             1500000.0    52   13   310  134   50  43.225806
# Jonathan Paul            3212600.0   306   72  1467  451   82  30.743013
# Jonathan Rafael           503800.0    55    7   263   80   19  30.418251
# Jonathan Rufino Jezus    1015500.0   180   31   760  201   22  26.447368
# Jordan James             1401500.0   157    9   711  242   92  34.036568
# Jordan Patrick            971000.0   206    6   722   99   32  13.711911
# Jordy Joe                1053500.0   225   15   900  162   62  18.000000
# Jorge Carlos             2666667.0    96   10   366  121   32  33.060109
# Jorge Luis              10672700.0   715   97  2598  442  155  17.013087
#
#                        HR/AB (%)   H/AB (%)  BB/SO (%)
# Name
# Johnathan Richard       3.710518  23.305734  33.451119
# Johnny Arthur           0.883002  27.152318  54.237288
# Johnny David            2.564895  28.260198  80.795455
# Johnny Pulado           2.029851  29.014925  44.919786
# Jolbert Alexis          1.309164  27.190332  28.323699
# Jon Corey               4.368261  27.260160  33.941606
# Jon Lewis               1.455026  25.264550  47.656250
# Jonathan Alejandro      0.998573  26.248217  56.310680
# Jonathan Charles        2.789024  28.565002  57.348703
# Jonathan Henry          1.208313  28.516191  43.631436
# Jonathan Johnson        4.477004  24.094424  40.832250
# Jonathan Lee            4.193548  16.774194  37.313433
# Jonathan Paul           4.907975  20.858896  18.181818
# Jonathan Rafael         2.661597  20.912548  23.750000
# Jonathan Rufino Jezus   4.078947  23.684211  10.945274
# Jordan James            1.265823  22.081575  38.016529
# Jordan Patrick          0.831025  28.531856  32.323232
# Jordy Joe               1.666667  25.000000  38.271605
# Jorge Carlos            2.732240  26.229508  26.446281
# Jorge Luis              3.733641  27.521170  35.067873
#                         Salary     H   HR    AB   SO   BB  SO/AB (%)  \
# Name
# Wilson              4421000.0   369   43  1352  374  115  27.662722
# Wilson Abraham      6561250.0   382   57  1492  276   91  18.498660
# Wilson Antonio      1490000.0   108    1   467   77   26  16.488223
# Wily Modesto        4823000.0   325   63  1283  415   84  32.346064
# Xander Jan          1060000.0   325   19  1151  239   71  20.764553
# Xavier Brooks        924500.0   110    9   441  110   40  24.943311
# Xavier Clifford    15992000.0   736   94  2674  561  165  20.979806
# Yadier Benjamin    67198500.0  1393   98  4922  501  375  10.178789
# Yan                 1550000.0   219   33   848  224   37  26.415094
# Yangervis Alfredo    516400.0   142   14   526   56   34  10.646388
# Yasiel             11928000.0   359   46  1222  287  129  23.486088
# Yasmani             1485000.0   168   31   732  207  123  28.278689
# Yasmany             5500000.0   111    9   406  110   17  27.093596
# Yoenis             59500000.0   609  106  2249  508  148  22.587817
# Yolmer Carlos        510000.0    87    5   389   81   19  20.822622
# Yonder              5150000.0   408   27  1504  232  153  15.425532
# Yorvit Adolfo      13071000.0   563   47  2161  410  162  18.972698
# Yunel              24597500.0  1144   73  4129  524  413  12.690724
# Yuniesky           18055000.0  1003   79  3841  411  132  10.700338
# Zachary Warren      3927500.0   444   40  1828  323   96  17.669584
#
#                    HR/AB (%)   H/AB (%)  BB/SO (%)
# Name
# Wilson              3.180473  27.292899  30.748663
# Wilson Abraham      3.820375  25.603217  32.971014
# Wilson Antonio      0.214133  23.126338  33.766234
# Wily Modesto        4.910366  25.331255  20.240964
# Xander Jan          1.650738  28.236316  29.707113
# Xavier Brooks       2.040816  24.943311  36.363636
# Xavier Clifford     3.515333  27.524308  29.411765
# Yadier Benjamin     1.991061  28.301503  74.850299
# Yan                 3.891509  25.825472  16.517857
# Yangervis Alfredo   2.661597  26.996198  60.714286
# Yasiel              3.764321  29.378069  44.947735
# Yasmani             4.234973  22.950820  59.420290
# Yasmany             2.216749  27.339901  15.454545
# Yoenis              4.713206  27.078702  29.133858
# Yolmer Carlos       1.285347  22.365039  23.456790
# Yonder              1.795213  27.127660  65.948276
# Yorvit Adolfo       2.174919  26.052753  39.512195
# Yunel               1.767983  27.706466  78.816794
# Yuniesky            2.056756  26.112991  32.116788
# Zachary Warren      2.188184  24.288840  29.721362

# %% [markdown]
# Taking a brief look at these stats we notice that they are fairly similar. Let's see if this quick glance holds true when we take the mean of each column.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('fivethirtyeight')

# 
low_mean = lowest_salaried[["Salary","SO/AB (%)","HR/AB (%)", "H/AB (%)", "BB/SO (%)"]].mean()
med_mean = medium_salaried[["Salary","SO/AB (%)","HR/AB (%)", "H/AB (%)", "BB/SO (%)"]].mean()
high_mean = highest_salaried[["Salary","SO/AB (%)","HR/AB (%)", "H/AB (%)", "BB/SO (%)"]].mean()

strikeout = [low_mean[1],med_mean[1],high_mean[1]]
homeruns = [low_mean[2],med_mean[2],high_mean[2]]
hits = [low_mean[3],med_mean[3],high_mean[3]]
bases = [low_mean[4],med_mean[4],high_mean[4]]
length = np.arange(3)
width = 0.2

# Now let's plot the graph!
fig, ax = plt.subplots(figsize=(8,5))

bar1 = ax.bar(length,strikeout,width,color=[0,0,0])
bar2 = ax.bar(length+width,homeruns,width,color=[230/255,159/255,0])
bar3 = ax.bar(length+(width*2),hits,width,color=[86/255,180/255,233/255])
bar4 = ax.bar(length+(width*3),bases,width,color=[0,158/255,115/255])

ax.set_ylabel('Percentage')
ax.set_title('Percentage by Salary')
ax.set_xticks(length + 0.29)
ax.set_xticklabels(('Low Salary', 'Medium Salary', 'High Salary'))

ax.legend((bar1[0], bar2[0], bar3[0],bar4[0]), ('SO/AB', 'HR/AB','H/AB','BB/SO'),loc=2)

plt.show()

# %% [markdown]
# This is actually quite interesting as this identifies our theory may be correct when looking at a low, medium and high salaried athletes. To confirm this trend holds true we are going to have to look at more than just 3 data points.
#
# ### Detailed Analysis
#
# Let's instead split the data frame into groups of 10 and take the average of each interval, graphing the results to analyze visually.

# %%
grouped_baseball_data = grouped_baseball_data.sort_values(by='Salary',ascending=True)

num_data_points = math.floor(grouped_baseball_data.shape[0]/10)
split_baseball_data = []
beg = 0

for i in range(0,num_data_points):
    split_baseball_data.append(grouped_baseball_data.iloc[(i*10):((i+1)*10)][["Salary","SO/AB (%)","HR/AB (%)", "H/AB (%)", "BB/SO (%)"]].mean())
    
index_vals = range(0,num_data_points)
column_vals = ['Salary', 'SO/AB (%)', 'HR/AB (%)', 'H/AB (%)', 'BB/SO (%)']
mean_baseball_data = pd.DataFrame(split_baseball_data, index = index_vals, columns=column_vals)
print(mean_baseball_data.head(5))
# Out:
#      Salary  SO/AB (%)  HR/AB (%)   H/AB (%)  BB/SO (%)
# 0  216050.0  24.332214   2.398318  24.536237  41.091905
# 1  275600.0  23.905667   2.508544  24.391077  46.123029
# 2  313500.0  21.241864   2.320195  23.503984  41.629357
# 3  335185.0  22.318092   2.228667  25.147386  27.082727
# 4  384500.0  23.436630   1.846512  25.685615  39.706222

# %% [markdown]
# The above is a sample of our new dataframe which we wil use to visually represent the overall trend we are seeing.

# %%
x_val = np.arange(0,num_data_points)


fig, axes = plt.subplots(nrows=2, ncols=2,figsize=(10,10))

# Graph 0,0
mean_baseball_data.plot(ax=axes[0,0],x=x_val,y='SO/AB (%)', kind='line',linewidth=1.0,alpha=0.5,title='SO/AB vs Interval Increase')
z = np.polyfit(x=x_val, y=mean_baseball_data['SO/AB (%)'], deg=1)
p = np.poly1d(z)

mean_baseball_data['SO/AB Trendline'] = p(x_val)

mean_baseball_data['SO/AB Trendline'].sort_index(ascending=False).plot(ax=axes[0,0],c='r', linewidth=1.5)
axes[0,0].legend(loc=1)
axes[0,0].xaxis.set_ticklabels([])

# Graph 0,1
mean_baseball_data.plot(ax=axes[0,1],x=x_val,y='HR/AB (%)', kind='line',linewidth=1.0,alpha=0.5,title='HR/AB vs Interval Increase')
z = np.polyfit(x=x_val, y=mean_baseball_data['HR/AB (%)'], deg=1)
p = np.poly1d(z)

mean_baseball_data['HR/AB Trendline'] = p(x_val)
mean_baseball_data['HR/AB Trendline'].sort_index(ascending=False).plot(ax=axes[0,1],c='r', linewidth=1.5)
axes[0,1].legend(loc=2)
axes[0,1].xaxis.set_ticklabels([])

# Graph 1, 0
mean_baseball_data.plot(ax=axes[1,0],x=x_val,y='H/AB (%)', kind='line',linewidth=1.0,alpha=0.5,title='H/AB vs Interval Increase')
z = np.polyfit(x=x_val, y=mean_baseball_data['H/AB (%)'], deg=1)
p = np.poly1d(z)

mean_baseball_data['HR/AB Trendline'] = p(x_val)
mean_baseball_data['HR/AB Trendline'].sort_index(ascending=False).plot(ax=axes[1,0],c='r', linewidth=1.5)
axes[1,0].legend(loc=2)

# Graph 1, 1
mean_baseball_data.plot(ax=axes[1,1],x=x_val,y='BB/SO (%)', kind='line',linewidth=1.0,alpha=0.5,title='BB/SO vs Interval Increase')
z = np.polyfit(x=x_val, y=mean_baseball_data['BB/SO (%)'], deg=1)
p = np.poly1d(z)

mean_baseball_data['BB/SO Trendline'] = p(x_val)
mean_baseball_data['BB/SO Trendline'].sort_index(ascending=False).plot(ax=axes[1,1],c='r', linewidth=1.5)
axes[1,1].legend(loc=2)


#mean_baseball_data.plot(x=np.arange(0,num_data_points),y='HR/AB (%)', kind='line',linewidth=1.0,alpha=0.5)

plt.show()

# %% [markdown]
# The four graphs seem to demonstrate our original hypothesis, the higher the salary interval the better the player.
#
# ### Confirmation of Hypothesis
#
# To be sure our hypothesis is correct we need to confirm by calculating the correlation coefficient and p-value using the pearson-r method. If we find that there is a high correlation we can be sure that our original hypothesis is correct.

# %%
import scipy.stats
x_val = np.arange(0,num_data_points)
corr_p_so = scipy.stats.pearsonr(x=x_val,y=mean_baseball_data['SO/AB (%)'])
corr_p_hr = scipy.stats.pearsonr(x=x_val,y=mean_baseball_data['HR/AB (%)'])
corr_p_h = scipy.stats.pearsonr(x=x_val,y=mean_baseball_data['H/AB (%)'])
corr_p_bb = scipy.stats.pearsonr(x=x_val,y=mean_baseball_data['BB/SO (%)'])

print('SO/AB: ',corr_p_so,'\n\n HR/AB: ',corr_p_hr,'\n\n H/AB: ',corr_p_h,'\n\n BB/SO: ',corr_p_bb)
# Out:
# SO/AB:  (-0.56573755183672836, 8.6080570709619152e-10)
#
#  HR/AB:  (0.68966410771611297, 2.1081581298532426e-15)
#
#  H/AB:  (0.81352352533274985, 8.3343521832403211e-25)
#
#  BB/SO:  (0.73949488248079787, 1.5434288993048112e-18)

# %% [markdown]
# The above print out shows that the r-value of each statistic we have been tracking is close to either 1 or -1. If we are to look at our null hypothesis, it states that the each of these values are not correlated to the salary interval. However, after looking at our pearson-r results we can see that each of the above have a high correlation and our p-values are incredibly small. This means we reject the null hypothesis and accept the alternative hypothesis which is that each of these statistics are correlated and dependent upon the salary value.

# %% [markdown]
# ## Conclusion
#
# Our analysis has concluded that as the salary interval increases, the better stats players will have. This analysis was based off of analyzing four different statistics which have followed the trend and undoubtedly proved that each of these values are correlated to one another using the pearson-r method. We are able to reject the null hypothesis and accept the alternative hypothesis which favours correlation between the values and the salary interval.
